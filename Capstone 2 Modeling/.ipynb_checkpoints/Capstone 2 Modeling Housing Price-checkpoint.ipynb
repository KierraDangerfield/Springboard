# %% [markdown]
# # Predict House Prices in King County, Washington
#
# ## Overview
#
# King County, Washington is the most populous county in Washington. It is also the 12th most populous in the United States. Washington's most populous city is Seattle.
#
# Our goal is to predict the price of a house based on houses sold between May 2014 to May 2015 in King County, Washington State, USA.

# %%
#imports 
import pandas as pd
import numpy as np
import opendatasets as od
from sklearn.linear_model import LinearRegression
#from sklearn.linear_model import LogisticRegression  
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.linear_model import Ridge
from sklearn import metrics
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import RobustScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# # 1. Data Wrangling

# %%
#get the data from API
housingAPI = od.download("https://www.kaggle.com/shivachandel/kc-house-data")
# Out:
# Skipping, found downloaded files in "./kc-house-data" (use force=True to force download)

# %%
#get the data and read it 
housingData = pd.read_csv('./kc-house-data/kc_house_data.csv')

# %%
#check for duplicates
housingData.duplicated()

duplicate = housingData[housingData.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
#check for any null values
housingData.isnull().values.any()

#check how many null values
housingData.isnull().sum()

# 2 null values are in the sqft_above column > index 10 & 17
housingData[housingData['sqft_above'].isna()]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 10  1736800520  20150403T000000  662500.0         3        2.5         3560
# 17  6865200140  20140529T000000  485000.0         4        1.0         1600
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 10      9796     1.0           0     0  ...      8         NaN           1700
# 17      4300     1.5           0     0  ...      7         NaN              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 10      1965             0    98007  47.6007 -122.145           2210
# 17      1916             0    98103  47.6648 -122.343           1610
#
#     sqft_lot15
# 10        8925
# 17        4300
#
# [2 rows x 21 columns]

# %%
#Remove the rows where sqft_above is not NA
newHousingDF = housingData[housingData['sqft_above'].notna()]

newHousingDF.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# We are going to create a correlation heatmap to view the correlation between features and price. We will also determine if there is any multi-collinearity > 0.95 that needs to be removed.

# %%
#here is a correlation heatmap
plt.subplots(figsize=(20,10))
sns.heatmap(newHousingDF.drop('id', axis=1).corr(), linewidths=.1, annot=True, cmap='magma');
plt.yticks(rotation=0);

# %% [markdown]
# There weren't any independent variables that were greater than 0.95.

# %% [markdown]
# # 2 Preprocessing and Training

# %% [markdown]
# ## 2.1 Train/Test split

# %%
X = newHousingDF.drop(columns=['id', 'date', 'price', 'sqft_basement', 'sqft_above'])
y = newHousingDF['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (15127, 16) (6484, 16) (15127,) (6484,)

# %%
#scale and transform X_train
scaler_train = RobustScaler().fit(X_train) 
X_train_scaled = scaler_train.transform(X_train)

#scale and transform test
scaler_test = RobustScaler().fit(X_test)
X_test_scaled = scaler_test.transform(X_test)

# %% [markdown]
# ### Variance Inflation Factor (VIF)

# %%
X_variables = X.copy()
X_variables = sm.add_constant(X_variables)

vif_data = pd.DataFrame()
vif_data['Features'] = X_variables.columns
vif_data["VIF"] = [variance_inflation_factor(X_variables.values, i) for i in range(len(X_variables.columns))]

round(vif_data, 2)
# Out:
# /Users/kierradangerfield/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#          Features         VIF
# 0           const  4496099.08
# 1        bedrooms        1.65
# 2       bathrooms        3.27
# 3     sqft_living        5.02
# 4        sqft_lot        2.10
# 5          floors        1.62
# 6      waterfront        1.20
# 7            view        1.40
# 8       condition        1.24
# 9           grade        3.35
# 10       yr_built        2.43
# 11   yr_renovated        1.15
# 12        zipcode        1.66
# 13            lat        1.16
# 14           long        1.77
# 15  sqft_living15        2.92
# 16     sqft_lot15        2.14

# %% [markdown]
# ### Metrics

# %%
#mean of house prices
np.mean(newHousingDF['price'])
# Out:
# 540085.0265142751

# %%
def r_squared(y, ypred):
    """R-squared score.
    Arguments:
    y -- the observed values
    ypred -- the predicted values
    """
    ybar = np.sum(y) / len(y) #yes, we could use np.mean(y)
    sum_sq_tot = np.sum((y - ybar)**2) #total sum of squares error
    sum_sq_res = np.sum((y - ypred)**2) #residual sum of squares error
    R2 = 1.0 - sum_sq_res / sum_sq_tot
    return R2

# %%
#Calculate the mean of `y_train`
train_mean = y_train.mean()
train_mean
# Out:
# 536078.3338401534

# %%
#init dummy regressor
dumb_reg = DummyRegressor(strategy='mean')
dumb_reg.fit(X_train, y_train)
dumb_reg.constant_
# Out:
# array([[536078.33384015]])

# %%
y_tr_pred = dumb_reg.predict(X_train)
y_tr_pred[:5]
# Out:
# array([536078.33384015, 536078.33384015, 536078.33384015, 536078.33384015,
#        536078.33384015])

# %%
y_te_pred = train_mean * np.ones(len(y_test))
r_squared(y_test, y_te_pred)
# Out:
# -0.0011777021976671076

# %%
#mean squared error function
def mse(y, ypred):
    """Mean square error.

    Arguments:
    y -- the observed values
    ypred -- the predicted values
    """
    sq_error = (y - ypred)**2
    mse = np.mean(sq_error)
    return mse

# %%
#root mean square error
metrics.mean_squared_error(y_test, y_te_pred, squared=False)
# Out:
# 389363.9424988386

# %% [markdown]
# ## 2.2 Linear regression
#
# Linear regression models shows a relationship between an independent variable(X) and an dependent variable (y). There are simple linear regression and multiple linear regression. A simple regression is between a single independent variable (X) and a corresponding dependent variable (y). Multiple linear regression is between two or more independent variables (X) and a corresponding dependent variable (y).

# %%
#statsmodel without being scaled 
X_train_sm = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train_sm).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     2186.
# Date:                Sat, 21 May 2022   Prob (F-statistic):               0.00
# Time:                        17:05:26   Log-Likelihood:            -2.0581e+05
# No. Observations:               15127   AIC:                         4.117e+05
# Df Residuals:                   15110   BIC:                         4.118e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.292e+07   3.39e+06      3.817      0.000    6.29e+06    1.96e+07
# bedrooms      -3.735e+04   2283.245    -16.360      0.000   -4.18e+04   -3.29e+04
# bathrooms      3.655e+04   3755.540      9.734      0.000    2.92e+04    4.39e+04
# sqft_living     168.0084      3.913     42.933      0.000     160.338     175.679
# sqft_lot          0.1469      0.054      2.711      0.007       0.041       0.253
# floors         1.932e+04   3747.277      5.155      0.000     1.2e+04    2.67e+04
# waterfront      5.55e+05   2.03e+04     27.318      0.000    5.15e+05    5.95e+05
# view             4.9e+04   2493.937     19.648      0.000    4.41e+04    5.39e+04
# condition      2.421e+04   2725.008      8.885      0.000    1.89e+04    2.96e+04
# grade          9.716e+04   2490.099     39.019      0.000    9.23e+04    1.02e+05
# yr_built      -2622.5469     84.833    -30.914      0.000   -2788.830   -2456.263
# yr_renovated     18.6648      4.261      4.381      0.000      10.313      27.016
# zipcode        -616.2614     38.455    -16.026      0.000    -691.638    -540.885
# lat            5.888e+05   1.24e+04     47.332      0.000    5.64e+05    6.13e+05
# long          -1.964e+05   1.52e+04    -12.922      0.000   -2.26e+05   -1.67e+05
# sqft_living15    26.3616      3.996      6.597      0.000      18.529      34.194
# sqft_lot15       -0.4236      0.089     -4.753      0.000      -0.598      -0.249
# ==============================================================================
# Omnibus:                    12556.822   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1194908.174
# Skew:                           3.438   Prob(JB):                         0.00
# Kurtosis:                      45.994   Cond. No.                     2.13e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/kierradangerfield/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# ### Interpreting the Coefficients
#
# <b>Coefficents</b> indicates the direction of the relationship between an <b>independent variable (X)</b> and a <b>dependent variable (y)</b>.
#
# For every one unit increae of the independent variable (X), the dependent variable (y) increases by the coefficient when all other variables are held constant.
#
# A positive sign indicates that as the independent variable(X) increases, the dependent variable(y) also increases. A negative sign indicates that as the independent variable(X) increases, the dependent variable(y) decreases.
#
#
# Let's explore our data. Our dependent variable is the 'price' column. Our independent variables are the other columns in our dataframe.
#
#
# <br/>
# <br/>
#
# For all of the <b>positive coefficents</b>, it is easy to determine that with the increase of those feature will result in an increase of the house price.
#
# For <b>bedrooms</b> there's a decrease of $3,679 in price for every bedroom increase in a house. The reason for this can be because as more rooms are added, there will be less room for bathrooms.
#
# For <b>yr_built</b> theres a derease of $2,635.03 in price for every year built increase in a house. The reason for this can be because the older homes are valued more compared to the newer homes.
#
# For <b>zipcode</b> there's a decrease of $605.10 in price for every zipcode number increase. This could be because as the zipcode increases, it can get closer to a zipcode with a lower average house price.
#
# For <b>long</b> there's a decrease of $197,300 in price for every longitude increase. This could be because as the longitude increases, it gets further away from Seattle, Washington, which has a longitude of -122.335167.
#
# For <b>sqft_lot15</b> there's a decrease of $0.39 in price for every increase in sqft_lot15.

# %%
#scaled statsmodel
X_tr_smScaled = sm.add_constant(pd.DataFrame(scaler_train.transform(X_train), index=X_train.index, columns = X_train.columns))
scaled_model = sm.OLS(y_train, X_tr_smScaled).fit()
print( scaled_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     2186.
# Date:                Sat, 21 May 2022   Prob (F-statistic):               0.00
# Time:                        17:05:26   Log-Likelihood:            -2.0581e+05
# No. Observations:               15127   AIC:                         4.117e+05
# Df Residuals:                   15110   BIC:                         4.118e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          4.419e+05   2844.179    155.371      0.000    4.36e+05    4.47e+05
# bedrooms      -3.735e+04   2283.245    -16.360      0.000   -4.18e+04   -3.29e+04
# bathrooms      3.655e+04   3755.540      9.734      0.000    2.92e+04    4.39e+04
# sqft_living    1.882e+05   4382.908     42.933      0.000     1.8e+05    1.97e+05
# sqft_lot        821.0259    302.875      2.711      0.007     227.355    1414.697
# floors         1.932e+04   3747.277      5.155      0.000     1.2e+04    2.67e+04
# waterfront      5.55e+05   2.03e+04     27.318      0.000    5.15e+05    5.95e+05
# view             4.9e+04   2493.937     19.648      0.000    4.41e+04    5.39e+04
# condition      2.421e+04   2725.008      8.885      0.000    1.89e+04    2.96e+04
# grade          9.716e+04   2490.099     39.019      0.000    9.23e+04    1.02e+05
# yr_built      -1.206e+05   3902.334    -30.914      0.000   -1.28e+05   -1.13e+05
# yr_renovated     18.6648      4.261      4.381      0.000      10.313      27.016
# zipcode       -5.238e+04   3268.675    -16.026      0.000   -5.88e+04    -4.6e+04
# lat            1.217e+05   2571.121     47.332      0.000    1.17e+05    1.27e+05
# long          -3.987e+04   3085.765    -12.922      0.000   -4.59e+04   -3.38e+04
# sqft_living15  2.293e+04   3476.523      6.597      0.000    1.61e+04    2.97e+04
# sqft_lot15    -2109.1146    443.776     -4.753      0.000   -2978.969   -1239.260
# ==============================================================================
# Omnibus:                    12556.822   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1194908.174
# Skew:                           3.438   Prob(JB):                         0.00
# Kurtosis:                      45.994   Cond. No.                     5.22e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/kierradangerfield/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# ### Let's visualize the difference between the scaled and unscaled statsmodel

# %%
#scaled_std_err_df['Features'] = scaled_std_err.index

# dataframe
df = pd.DataFrame()

#get unscaled coef
df['Scaled Coef'] = scaled_model.params
df['Scaled Std Err'] = scaled_model.bse

df = df.sort_values(by='Scaled Coef', ascending=False)

df = df.drop(index='const')
df
# Out:
#                  Scaled Coef  Scaled Std Err
# waterfront     554966.461840    20315.300481
# sqft_living    188169.394577     4382.908277
# lat            121696.900315     2571.120703
# grade           97161.195645     2490.098668
# view            49000.734856     2493.936691
# bathrooms       36554.722649     3755.540415
# condition       24212.067843     2725.008005
# sqft_living15   22934.599732     3476.523489
# floors          19318.790012     3747.277010
# sqft_lot          821.025859      302.874789
# yr_renovated       18.664753        4.260722
# sqft_lot15      -2109.114603      443.775885
# bedrooms       -37354.648390     2283.244852
# long           -39873.336245     3085.764507
# zipcode        -52382.219904     3268.674648
# yr_built      -120637.156521     3902.333662

# %% [markdown]
# ### Let's view the bar plot of the coefficients

# %%
#plot the coef with the constant
color= ['#AB46D2']

#error = scaled_model.bse
error = df['Scaled Std Err']
df['Scaled Coef'].plot.bar(figsize=(15,10), color=color, yerr=[error])

plt.xlabel('Feature Columns')
plt.ylabel("Coef")
plt.title('Scaled Coef of Statsmodel with constant')
# Out:
# Text(0.5, 1.0, 'Scaled Coef of Statsmodel with constant')

# %% [markdown]
# <b>Linear Regression Model</b>

# %%
#create linear regression object and train the train on the model
lm = LinearRegression().fit(X_train_scaled, y_train)

# %%
#y-intercept
print(lm.intercept_)
print(lm.coef_)
# Out:
# 441903.18126556324
# [-3.73546484e+04  3.65547226e+04  1.88169395e+05  8.21025859e+02
#   1.93187900e+04  5.54966462e+05  4.90007349e+04  2.42120678e+04
#   9.71611956e+04 -1.20637157e+05  1.86647526e+01 -5.23822199e+04
#   1.21696900e+05 -3.98733362e+04  2.29345997e+04 -2.10911460e+03]

# %%
#pred
y_pred = lm.predict(X_test_scaled)

#root mean square error
print(metrics.mean_squared_error(y_test, y_pred, squared=False))
# Out:
# 213499.38752335028

# %% [markdown]
# ## 2.3 Ridge regression
#
# <a herf='https://www.mygreatlearning.com/blog/what-is-ridge-regression/#:~:text=Ridge%20regression%20is%20a%20model,away%20from%20the%20actual%20values.'>Ridge regression</a> is a model tuning method that is used to analyse any data that suffers from multicollinearity. This method performs L2 regularization. When the issue of multicollinearity occurs, least-squares are unbiased, and variances are large, this results in predicted values being far away from the actual values.

# %%
ridge = Ridge().fit(X_train_scaled, y_train)

# %%
#y-intercept
print(ridge.intercept_)
#coef
print(ridge.coef_)
# Out:
# 441882.02112592664
# [-3.73588265e+04  3.65611208e+04  1.88121476e+05  8.20012156e+02
#   1.93258409e+04  5.49115682e+05  4.92771981e+04  2.42200039e+04
#   9.71561877e+04 -1.20593984e+05  1.87518956e+01 -5.23589650e+04
#   1.21670078e+05 -3.98708581e+04  2.29450881e+04 -2.10686255e+03]

# %%
#root mean square error
y_pred = ridge.predict(X_test_scaled)
metrics.mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 213518.9603888379

# %% [markdown]
# <b>We are going to use Gridsearchcv</b>

# %%
ridge.get_params().keys()
# Out:
# dict_keys(['alpha', 'copy_X', 'fit_intercept', 'max_iter', 'normalize', 'random_state', 'solver', 'tol'])

# %%
ridge_params = {'alpha':[.001,.01,.1,1,10,100]}

# %%
ridge_gs = GridSearchCV(ridge, ridge_params, cv = 5)
ridge_gs.fit(X_train_scaled, y_train)

print(ridge_gs.best_params_)
# Out:
# {'alpha': 1}

# %%
#get the best scores 
print(ridge_gs.best_score_)
# Out:
# 0.6950426784416319

# %%
#best model
ridge_gs.best_estimator_
# Out:
# Ridge(alpha=1)

# %%
#root mean square error
y_pred = ridge.predict(X_test_scaled)
metrics.mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 213518.9603888379

# %% [markdown]
# ## 2.4 Random Forest
#
# <a href='https://builtin.com/data-science/random-forest-python'>Random forest</a> is a supervised learning algorithm that uses an ensemble learning method for classification and regression. Random forest is a bagging technique and not a boosting technique. The trees in random forests run in parallel, meaning is no interaction between these trees while building the trees.

# %%
rf = RandomForestRegressor().fit(X_train_scaled, y_train)

# %%
#root mean square error
y_pred = rf.predict(X_test_scaled)
metrics.mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 137626.0327097123

# %% [markdown]
# <b>We are going to use Gridsearchcv</b>

# %%
rf.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
rf_params = {'n_estimators':[300],'max_depth': [30],'max_features': ['auto'] }

#rf_params = {'max_depth': [None, 5, 10, 20, 30],'max_features': ['auto', 'sqrt', 'log2'],'bootstrap': [True, False],'n_estimators':[100, 200, 300, 400]}

# %%
rf_gs = GridSearchCV(rf, rf_params, cv = 3)
rf_gs.fit(X_train_scaled, y_train)

print(rf_gs.best_params_)
# Out:
# {'max_depth': 30, 'max_features': 'auto', 'n_estimators': 300}

# %%
#get the best scores 
print(rf_gs.best_score_)
# Out:
# 0.8679948795529565

# %%
#best model
print(rf_gs.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=30, n_estimators=300)

# %%
#root mean square error
y_pred = rf.predict(X_test_scaled)
print(metrics.mean_squared_error(y_test, y_pred, squared=False))
# Out:
# 137626.0327097123

# %% [markdown]
# ### View Feature Importance

# %%
#feature importance
feature_importances = pd.DataFrame(rf.feature_importances_,index = X_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)

feature_importances
# Out:
#                importance
# grade            0.299989
# sqft_living      0.286764
# lat              0.161630
# long             0.067563
# sqft_living15    0.036858
# waterfront       0.033186
# yr_built         0.032102
# zipcode          0.016731
# sqft_lot         0.015258
# sqft_lot15       0.015098
# view             0.012414
# bathrooms        0.010155
# bedrooms         0.003642
# condition        0.003188
# floors           0.002739
# yr_renovated     0.002682

# %% [markdown]
# Based off of the importance, bedrooms, conditions,yr_renovated, and floors are insignificant because they are less than 0.01. I am going to plot the important features based on the feature importance.

# %%
#plot importance
feature_importances[:12].plot(kind='barh').invert_yaxis()

# %%
#shap feature importance
import shap
# load JS visualization code to notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X)

# %%
#plot
i = 4
shap.force_plot(explainer.expected_value, shap_values[i], features=X.iloc[i], feature_names=X.columns)

# %%
#summary bar plot
shap.summary_plot(shap_values, features=X, feature_names=X.columns, plot_type='bar')

# %% [markdown]
# Based on the Random Forest feature importance, 'grade', 'sqft_living', 'lat', 'long' are the top four features.
#
# Based on the Shap chart, 'sqft_living', 'grade', 'long', and 'sqft_above' are the top four features.
#
# <b>The Random Forest model had the lowest root mean square error of 141767.5261241599. We will use this model for predicting the housing prices.</b>
#
# # 3 Modeling

# %%
#rf_model = RandomForestRegressor(max_depth=30, max_features='auto', n_estimators=300)
#rf_model = RandomForestRegressor(max_features= 'sqrt', n_estimators= 400, max_depth=10, bootstrap=False)
rf_model = RandomForestRegressor(max_depth=30, max_features='auto', n_estimators=400)
rf_model.fit(X_train_scaled, y_train)

# %%
#root mean square error
y_pred = rf_model.predict(X_test_scaled)
metrics.mean_squared_error(y_test, y_pred, squared=False)

# %%
#Making an prediction
prediction = rf_model.predict(X_test_scaled)
print(prediction)

# %%
#test r2 score
from sklearn.metrics import r2_score
r2_score(y_test, prediction)

# %%
#train r2 score
prediction2 = rf_model.predict(X_train_scaled)
r2_score(y_train, prediction2)

# %%
"""print(y_train[:10])
print(prediction2[:10])"""

# %% [markdown]
# Based on the R² score, it tells us that it is 87.6% fitted to the data. However, there is some overfiitingin the training set. Below I tried with different input features.
#
# Let's plot the Actual vs Predicted

# %%
actualVSpredDF = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
actualVSpredDF

# %%
plt.figure(figsize=(5, 5))

ax = sns.histplot(actualVSpredDF['Actual'], color="r", label="Actual Value")
sns.histplot(actualVSpredDF['Predicted'], color="b", label="Predicted Values", ax=ax)

ax.legend()

plt.title('Actual vs Predicted Values for Price')


plt.show()
plt.close()

# %%
plt.figure(figsize=(5, 5))

ax = sns.scatterplot(y='Actual', data=actualVSpredDF, x=actualVSpredDF.index, color="r", label="Actual Value")
sns.scatterplot(y='Predicted', data=actualVSpredDF, x=actualVSpredDF.index, color="b", label="Predicted Values", ax=ax)

ax.legend()

plt.title('Actual vs Predicted Values for Price')


plt.show()
plt.close()

# %% [markdown]
# ### Residuals plot

# %%
from yellowbrick.regressor import ResidualsPlot

visualizer = ResidualsPlot(rf_model, hist=False)
visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()

# %% [markdown]
# ## Random Forest Model 2
#
# This model is without the insignificant variables based on the Random Forest Regressor

# %%
X = newHousingDF.drop(columns=['id', 'date', 'price', 'sqft_basement', 'sqft_above', 'condition', 
                               'yr_renovated', 'bedrooms', 'floors'])

y= newHousingDF['price']

#train/split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=47)

#scale and transform X_train
scaler_train = RobustScaler().fit(X_train) 
X_train_scaled = scaler_train.transform(X_train)

#scale and transform test
scaler_test = RobustScaler().fit(X_test)
X_test_scaled = scaler_test.transform(X_test)

# %%
rf_model2 = RandomForestRegressor(max_depth=30, max_features='auto', n_estimators=400)
rf_model2.fit(X_train_scaled, y_train)

# %%
#root mean square error
y_pred = rf_model2.predict(X_test_scaled)
metrics.mean_squared_error(y_test, y_pred, squared=False)

# %%
#Making an prediction
prediction = rf_model2.predict(X_test_scaled)
print(prediction)

# %%
#test r2 score
r2_score(y_test, prediction)

# %%
#train r2 score
train_prediction = rf_model2.predict(X_train_scaled)
r2_score(y_train, train_prediction)

# %% [markdown]
# ## Random Forest Model 3
#
# This model is with the top important variables based on the Random Forest Regressor and SHAP feature importance.

# %%
X = newHousingDF[['sqft_living', 'grade', 'lat','long', 'sqft_above']]

y= newHousingDF['price']

#train/split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=47)

#scale and transform X_train
scaler_train = RobustScaler().fit(X_train) 
X_train_scaled = scaler_train.transform(X_train)

#scale and transform test
scaler_test = RobustScaler().fit(X_test)
X_test_scaled = scaler_test.transform(X_test)

# %%
rf_model3 = RandomForestRegressor(max_depth=30, max_features='auto', n_estimators=400)
rf_model3.fit(X_train_scaled, y_train)

# %%
#root mean square error
y_pred = rf_model3.predict(X_test_scaled)
metrics.mean_squared_error(y_test, y_pred, squared=False)

# %%
#Making an prediction
prediction = rf_model3.predict(X_test_scaled)
print(prediction)

# %%
#test r2 score
r2_score(y_test, prediction)

# %%
#train r2 score
train_prediction = rf_model3.predict(X_train_scaled)
r2_score(y_train, train_prediction)

# %% [markdown]
# My original model (rf_model) is the one that has performed the best even though it has the insignificant features.

# %%
#X = newHousingDF[['sqft_living', 'grade', 'lat','long', 'sqft_above', 'sqft_living15', 'waterfront', 'yr_built']]
