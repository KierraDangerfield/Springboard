# %% [markdown]
# # Storytelling with Dogs of Zurich
#
# Exploring the data to determine if there is a trend of dog owners and their dog's breed.

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#get the data and read it 
dogData = pd.read_csv('./20170308hundehalter.csv')

# %%
#lets view
dogData.head(10)
# Out:
#    HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER              RASSE1  \
# 0        126  61-70          m         9.0           92.0       Welsh Terrier
# 1        171  61-70          m         3.0           31.0   Berner Sennenhund
# 2        574  61-70          w         2.0           23.0     Mischling gross
# 3        695  41-50          m         6.0           63.0  Labrador Retriever
# 4        893  61-70          w         7.0           71.0     Mittelschnauzer
# 5       1177  51-60          m        10.0          102.0            Shih Tzu
# 6       4004  61-70          w         3.0           34.0              Dackel
# 7       4050  41-50          w        11.0          111.0        Bichon frisé
# 8       4054  51-60          w        11.0          111.0   Lagotto Romagnolo
# 9       4155  61-70          w         9.0           92.0         Zwergdackel
#
#   RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  GEBURTSJAHR_HUND  \
# 0              NaN    NaN               NaN         K              2011
# 1              NaN    NaN               NaN         I              2009
# 2              NaN    NaN               NaN         I              2013
# 3              NaN    NaN               NaN         I              2012
# 4              NaN    NaN               NaN         I              2010
# 5              NaN    NaN               NaN         K              2011
# 6              NaN    NaN               NaN         K              2010
# 7              NaN    NaN               NaN         K              2012
# 8              NaN    NaN               NaN         I              2016
# 9              NaN    NaN               NaN         K              2002
#
#   GESCHLECHT_HUND     HUNDEFARBE
# 0               w  schwarz/braun
# 1               m       tricolor
# 2               w        schwarz
# 3               w          braun
# 4               w        schwarz
# 5               m  schwarz/weiss
# 6               m          braun
# 7               m          weiss
# 8               w    weiss/beige
# 9               m   schwarz/grau

# %% [markdown]
# ALTER -> Age
#
# GESCHLECHT -> Gender
#
# STADTKREIS -> City Quarter or District
#
# RASSE1 -> Dog's Primary Breed
#
# RASSE2 -> Dog's Secondary Breed
#
# GEBURTSJAHR_HUND -> Dog's Year of Birth
#
# GESCHLECHT_HUND -> Dog's Gender
#
# HUNDEFARBE -> Dog's Colo

# %%
#let's rename the columns
dogData.rename(columns={'ALTER': "Owner's Age",
                       'GESCHLECHT': "Owner's Gender",
                       'STADTKREIS': 'City Quarter or District',
                       'RASSE1': "Dog's Primary Breed",
                       'RASSE2': "Dog's Secondary Breed",
                       'GEBURTSJAHR_HUND': "Dog's Birth Year",
                       'GESCHLECHT_HUND': "Dog's Gender",
                       'HUNDEFARBE': "Dog's Colo"}, inplace=True)

dogData
# Out:
#       HALTER_ID Owner's Age Owner's Gender  City Quarter or District  \
# 0           126       61-70              m                       9.0
# 1           171       61-70              m                       3.0
# 2           574       61-70              w                       2.0
# 3           695       41-50              m                       6.0
# 4           893       61-70              w                       7.0
# ...         ...         ...            ...                       ...
# 7150     135718       31-40              m                       9.0
# 7151     135725       31-40              w                       7.0
# 7152     135726       11-20              w                      11.0
# 7153     135728       31-40              w                       7.0
# 7154     135731       21-30              m                       9.0
#
#       STADTQUARTIER Dog's Primary Breed RASSE1_MISCHLING  \
# 0              92.0       Welsh Terrier              NaN
# 1              31.0   Berner Sennenhund              NaN
# 2              23.0     Mischling gross              NaN
# 3              63.0  Labrador Retriever              NaN
# 4              71.0     Mittelschnauzer              NaN
# ...             ...                 ...              ...
# 7150           91.0     Mischling gross              NaN
# 7151           74.0               Boxer              NaN
# 7152          111.0            Pinscher              NaN
# 7153           72.0             Whippet              NaN
# 7154           91.0      Cocker Spaniel              NaN
#
#      Dog's Secondary Breed  RASSE2_MISCHLING RASSENTYP  Dog's Birth Year  \
# 0                      NaN               NaN         K              2011
# 1                      NaN               NaN         I              2009
# 2                      NaN               NaN         I              2013
# 3                      NaN               NaN         I              2012
# 4                      NaN               NaN         I              2010
# ...                    ...               ...       ...               ...
# 7150                   NaN               NaN         I              2015
# 7151                   NaN               NaN         I              2016
# 7152                   NaN               NaN         K              2016
# 7153                   NaN               NaN         I              2016
# 7154                   NaN               NaN         K              2016
#
#      Dog's Gender     Dog's Colo
# 0               w  schwarz/braun
# 1               m       tricolor
# 2               w        schwarz
# 3               w          braun
# 4               w        schwarz
# ...           ...            ...
# 7150            w         golden
# 7151            w     gelb/weiss
# 7152            w        schwarz
# 7153            w     vierfarbig
# 7154            m        schwarz
#
# [7155 rows x 13 columns]

# %%
#get dog age 
dogData['dog_age'] = 2017 - dogData["Dog's Birth Year"]
dogData
# Out:
#       HALTER_ID Owner's Age Owner's Gender  City Quarter or District  \
# 0           126       61-70              m                       9.0
# 1           171       61-70              m                       3.0
# 2           574       61-70              w                       2.0
# 3           695       41-50              m                       6.0
# 4           893       61-70              w                       7.0
# ...         ...         ...            ...                       ...
# 7150     135718       31-40              m                       9.0
# 7151     135725       31-40              w                       7.0
# 7152     135726       11-20              w                      11.0
# 7153     135728       31-40              w                       7.0
# 7154     135731       21-30              m                       9.0
#
#       STADTQUARTIER Dog's Primary Breed RASSE1_MISCHLING  \
# 0              92.0       Welsh Terrier              NaN
# 1              31.0   Berner Sennenhund              NaN
# 2              23.0     Mischling gross              NaN
# 3              63.0  Labrador Retriever              NaN
# 4              71.0     Mittelschnauzer              NaN
# ...             ...                 ...              ...
# 7150           91.0     Mischling gross              NaN
# 7151           74.0               Boxer              NaN
# 7152          111.0            Pinscher              NaN
# 7153           72.0             Whippet              NaN
# 7154           91.0      Cocker Spaniel              NaN
#
#      Dog's Secondary Breed  RASSE2_MISCHLING RASSENTYP  Dog's Birth Year  \
# 0                      NaN               NaN         K              2011
# 1                      NaN               NaN         I              2009
# 2                      NaN               NaN         I              2013
# 3                      NaN               NaN         I              2012
# 4                      NaN               NaN         I              2010
# ...                    ...               ...       ...               ...
# 7150                   NaN               NaN         I              2015
# 7151                   NaN               NaN         I              2016
# 7152                   NaN               NaN         K              2016
# 7153                   NaN               NaN         I              2016
# 7154                   NaN               NaN         K              2016
#
#      Dog's Gender     Dog's Colo  dog_age
# 0               w  schwarz/braun        6
# 1               m       tricolor        8
# 2               w        schwarz        4
# 3               w          braun        5
# 4               w        schwarz        7
# ...           ...            ...      ...
# 7150            w         golden        2
# 7151            w     gelb/weiss        1
# 7152            w        schwarz        1
# 7153            w     vierfarbig        1
# 7154            m        schwarz        1
#
# [7155 rows x 14 columns]

# %%
#Owners' age vs Dogs' Age
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.barplot(y="dog_age", x=dogData["Owner's Age"].sort_values(ascending=True), hue= "Owner's Gender", data=dogData).set(title="Owners' Age vs Dogs' Age")

# %%
#Top breeds
topDog = dogData["Dog's Primary Breed"].value_counts()
topDog.head(20)
# Out:
# Mischling klein                620
# Chihuahua                      516
# Labrador Retriever             439
# Yorkshire Terrier              298
# Jack Russel Terrier            290
# Französische Bulldogge         213
# Mischling gross                206
# Malteser                       205
# Mops                           171
# Golden Retriever               153
# Pudel                          100
# Bolonka Zwetna                 100
# Border Collie                   98
# Beagle                          95
# West Highland White Terrier     92
# Zwergspitz                      88
# Pinscher                        87
# Schäfer                         84
# Pekingese                       81
# Shih Tzu                        77
# Name: Dog's Primary Breed, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,10))

topDog[0:20].plot(kind='bar', title="Top 20 dog breeds")

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ## The top dog breeds are the following:
#
# 1. Mischling klein
# 2. Chihuahua
# 3. Labrador Retriever
# 4. Yorkshire Terrier
# 5. Jack Russel Terrier
# 6. Französische Bulldogge

# %% [markdown]
# # Top Dogs Based on Age Group

# %% [markdown]
# ## Top breeds based on 11-20, 21-30, 31-40 age group

# %%
#Top breeds based on 31-40 age group
elevon_20 = dogData[dogData["Owner's Age"] == "11-20"]
twentyone_30 = dogData[dogData["Owner's Age"] == "21-30"]
thirtyone_40 = dogData[dogData["Owner's Age"] == "31-40"]


fig, (ax1, ax2, ax3) = plt.subplots(ncols=1, nrows=3, figsize=(15,25))
fig.suptitle("Age Groups vs Dog Breeds")


sns.countplot(y="Dog's Primary Breed", data=elevon_20, hue="Owner's Gender", 
              order=elevon_20["Dog's Primary Breed"].value_counts().iloc[:15].index, 
              ax=ax1).set(title="Owners' Age: 11-20 vs Dogs' Breed")

sns.countplot(y="Dog's Primary Breed", data=twentyone_30, hue="Owner's Gender", 
              order=twentyone_30["Dog's Primary Breed"].value_counts().iloc[:15].index, 
              ax=ax2).set(title="Owners' Age:  21-30 vs Dogs' Breed")

sns.countplot(y="Dog's Primary Breed", data=thirtyone_40, hue="Owner's Gender", 
              order=thirtyone_40["Dog's Primary Breed"].value_counts().iloc[:15].index,
              ax=ax3).set(title="Owners' Age: 31-40 vs Dogs' Breed")

plt.rcParams['font.size'] = '16'

ax1.tick_params(axis='x', labelrotation=90)
ax2.tick_params(axis='x', labelrotation=90)
ax3.tick_params(axis='x', labelrotation=90)

for (x, y, z) in zip(ax1.containers, ax2.containers, ax3.containers):
    ax1.bar_label(x)
    ax2.bar_label(y)
    ax3.bar_label(z)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Top dog based on Owner's Gender and Age Group
#
# Women 11-20 age group: Chihuahua
#
# Women 21-30 age group: Chihuahua
#
# Women 31-40 age group: Chihuahua
#
# <br/><br/>
#
#
# Men 11-20 age group: Dogo Argentino
#
# Men 21-30 age group: Französische Bulldogge (French Bulldog)
#
# Men 31-40 age group: Labrador Retriever

# %% [markdown]
# ## Top breeds based on 41-50,  51-60, 61-70  age group

# %%
#Top breeds based on 61-70 age group
fortyone_50 = dogData[dogData["Owner's Age"] == "41-50"]
fiftyone_60 = dogData[dogData["Owner's Age"] == "51-60"]
sixtyone_70 = dogData[dogData["Owner's Age"] == "61-70"]


fig, (ax1, ax2, ax3) = plt.subplots(ncols=1, nrows=3, figsize=(15,25))
fig.suptitle("Age Groups vs Dog Breeds")


sns.countplot(y="Dog's Primary Breed", data=fortyone_50, hue="Owner's Gender", 
              order=fortyone_50["Dog's Primary Breed"].value_counts().iloc[:15].index, 
              ax=ax1).set(title="Owners' Age: 41-50 vs Dogs' Breed")

sns.countplot(y="Dog's Primary Breed", data=fiftyone_60, hue="Owner's Gender", 
              order=fiftyone_60["Dog's Primary Breed"].value_counts().iloc[:15].index, 
              ax=ax2).set(title="Owners' Age:  51-60 vs Dogs' Breed")

sns.countplot(y="Dog's Primary Breed", data=sixtyone_70, hue="Owner's Gender", 
              order=sixtyone_70["Dog's Primary Breed"].value_counts().iloc[:15].index,
              ax=ax3).set(title="Owners' Age: 61-70 vs Dogs' Breed")

plt.rcParams['font.size'] = '16'

ax1.tick_params(axis='x', labelrotation=90)
ax2.tick_params(axis='x', labelrotation=90)
ax3.tick_params(axis='x', labelrotation=90)

for (x, y, z) in zip(ax1.containers, ax2.containers, ax3.containers):
    ax1.bar_label(x)
    ax2.bar_label(y)
    ax3.bar_label(z)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Top dog based on Owner's Gender and Age Group
#
# Women 41-50 age group: Mischling klein
#
# Women 51-60 age group: Mischling klein
#
# Women 61-70 age group: Mischling klein
#
# <br/><br/>
#
#
# Men 41-50 age group: Labrador Retriever
#
# Men 51-60 age group: Mischling klein
#
# Men 61-70 age group: Mischling klein

# %% [markdown]
# ## Top breeds based on 71-80, 81-90, 91-100 age group

# %%
#Top breeds vs cities

eightyone_90 = dogData[dogData["Owner's Age"] == "81-90"]
ninetyone_100 = dogData[dogData["Owner's Age"] == "91-100"]
seventyone_80 = dogData[dogData["Owner's Age"] == "71-80"]


fig, (ax1, ax2, ax3) = plt.subplots(ncols=1, nrows=3, figsize=(15,25))
fig.suptitle("Age Groups vs Dog Breeds")


sns.countplot(y="Dog's Primary Breed", data=seventyone_80, hue="Owner's Gender", 
              order=seventyone_80["Dog's Primary Breed"].value_counts().iloc[:15].index, 
              ax=ax1).set(title="Owners' Age: 71-80 vs Dogs' Breed")
#ax[0].xticks(rotation = 45)

sns.countplot(y="Dog's Primary Breed", data=eightyone_90, hue="Owner's Gender", 
              order=eightyone_90["Dog's Primary Breed"].value_counts().iloc[:15].index, 
              ax=ax2).set(title="Owners' Age:  81-90 vs Dogs' Breed")

sns.countplot(y="Dog's Primary Breed", data=ninetyone_100, hue="Owner's Gender", 
              order=ninetyone_100["Dog's Primary Breed"].value_counts().iloc[:15].index,
              ax=ax3).set(title="Owners' Age: 91-100 vs Dogs' Breed")

plt.rcParams['font.size'] = '16'

ax1.tick_params(axis='x', labelrotation=90)
ax2.tick_params(axis='x', labelrotation=90)
ax3.tick_params(axis='x', labelrotation=90)

for (x, y, z) in zip(ax1.containers, ax2.containers, ax3.containers):
    ax1.bar_label(x)
    ax2.bar_label(y)
    ax3.bar_label(z)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Top dog based on Owner's Gender and Age Group

# %%
data = {"Owner's Gender": ['Women', 'Women', 'Women', 'Women', 'Women', 
                           'Women', 'Women', 'Women', 'Women', 'Men', 'Men',
                          'Men', 'Men', 'Men', 'Men', 'Men', 'Men', 'Men'],
       "Age Group": ["11-20", "21-30", "31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100", 
                     "11-20", "21-30", "31-40", "41-50", "51-60", "61-70", "71-80", "81-90", "91-100"],
       "Top Breed" : ["Chihuahua", "Chihuahua", "Chihuahua", "Mischling klein", "Mischling klein", 
                      "Mischling klein", "Mischling klein", "Poodle", "Mischling klein & Poodle",
                     "Dogo Argentino", "French Bulldog", "Labrador Retriever", "Labrador Retriever",
                     "Mischling klein", "Mischling klein", "Labrador Retriever", "Mischling klein & Poodle",
                     "Labrador Retriever, Coton de Tulear, Jack Russel Terrier, and Vizsla)"]}

df = pd.DataFrame(data)

df
# Out:
#    Owner's Gender Age Group                                          Top Breed
# 0           Women     11-20                                          Chihuahua
# 1           Women     21-30                                          Chihuahua
# 2           Women     31-40                                          Chihuahua
# 3           Women     41-50                                    Mischling klein
# 4           Women     51-60                                    Mischling klein
# 5           Women     61-70                                    Mischling klein
# 6           Women     71-80                                    Mischling klein
# 7           Women     81-90                                             Poodle
# 8           Women    91-100                           Mischling klein & Poodle
# 9             Men     11-20                                     Dogo Argentino
# 10            Men     21-30                                     French Bulldog
# 11            Men     31-40                                 Labrador Retriever
# 12            Men     41-50                                 Labrador Retriever
# 13            Men     51-60                                    Mischling klein
# 14            Men     61-70                                    Mischling klein
# 15            Men     71-80                                 Labrador Retriever
# 16            Men     81-90                           Mischling klein & Poodle
# 17            Men    91-100  Labrador Retriever, Coton de Tulear, Jack Russ...
